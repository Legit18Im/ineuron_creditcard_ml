# %% [markdown]
# # Credit Card - Exploratory Data Analysis - Jay Shahapurakar

# %% [markdown]
# # Read Dataset

# %%
from warnings import filterwarnings
filterwarnings('ignore')
#conda install -n vnve ipykernel --update-deps --force-reinstall

# %%
import pandas as pd
df = pd.read_csv(r"E:\INeuron_Project\ineuron_creditcard_ml\UCI_Credit_Card.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# # Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %% [markdown]
# # Checking Missing Data

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# # Converting Sex, Education and Marriage columns to Object

# %%
df['SEX']=df['SEX'].astype(str)
df['EDUCATION']=df['EDUCATION'].astype(str)
df['MARRIAGE']=df['MARRIAGE'].astype(str)
df['default.payment.next.month']=df['default.payment.next.month'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %% [markdown]
# # Drop Statistically insignificant column - ID

# %%
df1 = df.drop(labels=['ID'],axis=1)
df1.head()
# Out:
#    LIMIT_BAL SEX EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0    20000.0   2         2        1   24      2      2     -1     -1     -2
# 1   120000.0   2         2        2   26     -1      2      0      0      0
# 2    90000.0   2         2        2   34      0      0      0      0      0
# 3    50000.0   2         2        1   37      0      0      0      0      0
# 4    50000.0   1         2        1   57     -1      0     -1      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# # Statistical Summarry for each column

# %%
df1.describe().T
# Out:
#              count           mean            std       min       25%  \
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# PAY_0      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# ...

# %% [markdown]
# # Checking for Categorical Data

# %%
df1.describe(include = 'object').T
# Out:
#                             count unique top   freq
# SEX                         30000      2   2  18112
# EDUCATION                   30000      7   2  14030
# MARRIAGE                    30000      4   2  15964
# default.payment.next.month  30000      2   0  23364

# %% [markdown]
# # Correlation

# %%
df1.corr()
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.024755  -0.219161 -0.108139
# SEX                          0.024755  1.000000   0.014232 -0.031389
# EDUCATION                   -0.219161  0.014232   1.000000 -0.143464
# MARRIAGE                    -0.108139 -0.031389  -0.143464  1.000000
# AGE                          0.144713 -0.090874   0.175061 -0.414170
# PAY_0                       -0.271214 -0.057643   0.105364  0.019917
# PAY_2                       -0.296382 -0.070771   0.121566  0.024199
# PAY_3                       -0.286123 -0.066096   0.114025  0.032688
# PAY_4                       -0.267460 -0.060173   0.108793  0.033122
# PAY_5                       -0.249411 -0.055064   0.097520  0.035629
# PAY_6                       -0.235195 -0.044008   0.082316  0.034345
# BILL_AMT1                    0.285430 -0.033642   0.023581 -0.023472
# BILL_AMT2                    0.278314 -0.031183   0.018749 -0.021602
# ...

# %%
import seaborn as sb
sb.distplot(df1['LIMIT_BAL'])
# Out:
# <Axes: xlabel='LIMIT_BAL', ylabel='Density'>

# %%
# Renaming Default Column Name
df1.rename(columns={'default.payment.next.month':'default'}, inplace=True)

# %% [markdown]
# # Categorical and Continuous variables seperation

# %%
import sys
sys.path.append("path_to_the_folder_containing_definitions")

# %%
from definitions import catcon
cat, con = catcon(df1)
# Out:
# Categorical and Continuous variables appended

# %%
cat
# Out:
# ['SEX', 'EDUCATION', 'MARRIAGE', 'default']

# %%
con
# Out:
# ['LIMIT_BAL',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %% [markdown]
# # Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(5,4,x)
    x=x+1
    sb.distplot(df1[i])

# %% [markdown]
# # Bivariate analysis with Target Variable

# %% [markdown]
# # Performing ANOVA with continuous variables

# %%
from definitions import ANOVA
q = []
for i in con:
    q.append(ANOVA(df1,"default",i))

# %%
anova_df = pd.DataFrame({'Column':con,'pval':q})
anova_df.sort_values(by='pval')
# Out:
#        Column     pval
# 0   LIMIT_BAL  0.00000
# 17   PAY_AMT4  0.00000
# 16   PAY_AMT3  0.00000
# 15   PAY_AMT2  0.00000
# 14   PAY_AMT1  0.00000
# 18   PAY_AMT5  0.00000
# 7       PAY_6  0.00000
# 19   PAY_AMT6  0.00000
# 5       PAY_4  0.00000
# 4       PAY_3  0.00000
# 3       PAY_2  0.00000
# 2       PAY_0  0.00000
# 6       PAY_5  0.00000
# 8   BILL_AMT1  0.00067
# 9   BILL_AMT2  0.01396
# 10  BILL_AMT3  0.01477
# 1         AGE  0.01614
# 11  BILL_AMT4  0.07856
# 12  BILL_AMT5  0.24163
# 13  BILL_AMT6  0.35212

# %%
imp_con_columns = list(anova_df[anova_df.pval<0.05]['Column'])
imp_con_columns
# Out:
# ['LIMIT_BAL',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %% [markdown]
# # Chi Square test for Categorical to Target

# %%
from definitions import chisquare
r = []
for i in cat:
    r.append(chisquare(df1,'default',i))

# %%
chi_df = pd.DataFrame({'Columns':cat,'Pval':r})
chi_df.sort_values(by='Pval')
# Out:
#      Columns          Pval
# 3    default  0.000000e+00
# 1  EDUCATION  1.233263e-32
# 0        SEX  4.944679e-12
# 2   MARRIAGE  8.825862e-08

# %%
imp_cat_columns = list(chi_df[chi_df['Pval']<0.05]['Columns'])
imp_cat_columns.remove('default')
imp_cat_columns
# Out:
# ['SEX', 'EDUCATION', 'MARRIAGE']

# %% [markdown]
# # BoxPlots with Target Variable

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(5,4,x)
    x=x+1
    sb.boxplot(data=df1,x='default',y=i)

# %% [markdown]
# # Relationship of continuous variables with Male/Female

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(5,4,x)
    x=x+1
    sb.boxplot(data=df1,x='SEX',y=i)

# %% [markdown]
# # Relation of Continuous variables with Education

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(5,4,x)
    x=x+1
    sb.boxplot(data=df1,x='EDUCATION',y=i)

# %% [markdown]
# # Relationship of Continuous variables with Marriage

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(5,4,x)
    x=x+1
    sb.boxplot(data=df1,x='MARRIAGE',y=i)
